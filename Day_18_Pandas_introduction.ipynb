# %% [markdown]
# <a href="https://colab.research.google.com/github/rranjithkumar100/AI-Training/blob/main/Day_18_Pandas_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#import local files using colab lib

import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e77e771-686f-4067-9ae2-c4f1428af66f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e77e771-686f-4067-9ae2-c4f1428af66f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("cars.csv")

# %%
df = pd.DataFrame(data)

# %%
df.size
# Out:
# 384

# %%
# Exploratory data analysis

#copy or swallow copy
dfCopy = df.copy()

# %%
df.head()
# Out:
#               Model    MPG  Cylinder   Disp     HP  Drat     Wt   Qsec  VS  \
# 0          Mazda RX4  21.0         6  160.0  110.0  3.90  2.620  16.46   0
# 1      Mazda RX4 Wag  21.0         6  160.0  110.0  3.90  2.875  17.02   0
# 2         Datsun 710  22.8         4  108.0   93.0  3.85  2.320  18.61   1
# 3     Hornet 4 Drive  21.4         6  258.0  110.0  3.08  3.215  19.44   1
# 4  Hornet Sportabout  18.7         8  360.0  175.0  3.15  3.440  17.02   0
#
#    AM  Gear  Carb
# 0   1     4     4
# 1   1     4     4
# 2   1     4     1
# 3   0     3     1
# 4   0     3     2

# %%
df.tail()
# Out:
#             Model    MPG  Cylinder   Disp     HP  Drat     Wt  Qsec  VS  AM  \
# 27    Lotus Europa  30.4         4   95.1  113.0  3.77  1.513  16.9   1   1
# 28  Ford Pantera L  15.8         8  351.0  264.0  4.22  3.170  14.5   0   1
# 29    Ferrari Dino  19.7         6  145.0  175.0  3.62  2.770  15.5   0   1
# 30   Maserati Bora  15.0         8  301.0  335.0  3.54  3.570  14.6   0   1
# 31      Volvo 142E  21.4         4  121.0  109.0  4.11  2.780  18.6   1   1
#
#     Gear  Carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.columns
# Out:
# Index(['Model ', 'MPG', 'Cylinder', 'Disp', 'HP', 'Drat', 'Wt', 'Qsec', 'VS',
#        'AM', 'Gear', 'Carb'],
#       dtype='object')
