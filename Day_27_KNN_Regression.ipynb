# %% [markdown]
# <a href="https://colab.research.google.com/github/rranjithkumar100/AI-Training/blob/main/Day_27_KNN_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-de02f9c1-bbb3-419f-9f5e-59985b48ab09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de02f9c1-bbb3-419f-9f5e-59985b48ab09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('02Students (1).csv')

# %%
df.head()
# Out:
#    Hours  sHours  Marks
# 0      0       6     34
# 1      1       7     36
# 2      1       6     33
# 3      1       8     39
# 4      1       8     42

# %%
df.count()
# Out:
# Hours     30
# sHours    30
# Marks     30
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Hours     0
# sHours    0
# Marks     0
# dtype: int64

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,2:3]

# %%
x.head()
# Out:
#    Hours  sHours
# 0      0       6
# 1      1       7
# 2      1       6
# 3      1       8
# 4      1       8

# %%
y.head()
# Out:
#    Marks
# 0     34
# 1     36
# 2     33
# 3     39
# 4     42

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=3)

# %%
x_train.shape
# Out:
# (21, 2)

# %%
x_test.shape
# Out:
# (9, 2)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test,y_predict)

# %%
mae
# Out:
# 4.622222222222223

# %%
mse = mean_squared_error(y_test, y_predict)

# %%
mse
# Out:
# 27.20888888888888

# %%
from sklearn.neighbors import KN
