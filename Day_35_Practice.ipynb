# %% [markdown]
# <a href="https://colab.research.google.com/github/rranjithkumar100/AI-Training/blob/main/Day_35_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84774d0f-aaa8-4386-b836-391a1b376ba0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84774d0f-aaa8-4386-b836-391a1b376ba0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Load the csv into dataframe
df = pd.read_csv('Day_33_corporate_stress.csv')

# %%
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Marital_Status', 'Job_Role', 'Experience_Years',
#        'Monthly_Salary_INR', 'Working_Hours_per_Week', 'Commute_Time_Hours',
#        'Remote_Work', 'Stress_Level', 'Health_Issues', 'Company_Size',
#        'Department', 'Sleep_Hours', 'Physical_Activity_Hours_per_Week',
#        'Mental_Health_Leave_Taken', 'Manager_Support_Level',
#        'Work_Pressure_Level', 'Annual_Leaves_Taken', 'Work_Life_Balance',
#        'Family_Support_Level', 'Job_Satisfaction', 'Performance_Rating',
#        'Team_Size', 'Training_Opportunities', 'Gender_Bias_Experienced',
#        'Discrimination_Experienced', 'Burnout_Symptoms', 'Location'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  ID           Age  Experience_Years  Monthly_Salary_INR  \
# count  50000.000000  50000.000000      50000.000000        50000.000000
# mean   25000.500000     41.518600         20.071580       110129.926165
# std    14433.901067     13.833279         11.835681        52069.676542
# min        1.000000     18.000000          0.000000        20001.960000
# 25%    12500.750000     30.000000         10.000000        64875.487500
# 50%    25000.500000     41.000000         20.000000       110168.205000
# 75%    37500.250000     54.000000         30.000000       155322.665000
# max    50000.000000     65.000000         40.000000       199992.800000
#
#        Working_Hours_per_Week  Commute_Time_Hours  Stress_Level   Sleep_Hours  \
# count             50000.00000        50000.000000  50000.000000  50000.000000
# mean                 62.53824            1.500454      5.004680      6.498888
# std                  16.16981            0.867738      3.154745      1.437200
# ...

# %%
df.isnull().sum()
# Out:
# ID                                      0
# Age                                     0
# Gender                                  0
# Marital_Status                          0
# Job_Role                                0
# Experience_Years                        0
# Monthly_Salary_INR                      0
# Working_Hours_per_Week                  0
# Commute_Time_Hours                      0
# Remote_Work                             0
# Stress_Level                            0
# Health_Issues                       12541
# Company_Size                            0
# Department                              0
# Sleep_Hours                             0
# Physical_Activity_Hours_per_Week        0
# Mental_Health_Leave_Taken               0
# Manager_Support_Level                   0
# Work_Pressure_Level                     0
# Annual_Leaves_Taken                     0
# Work_Life_Balance                       0
# Family_Support_Level                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ID                                50000 non-null  int64
#  1   Age                               50000 non-null  int64
#  2   Gender                            50000 non-null  object
#  3   Marital_Status                    50000 non-null  object
#  4   Job_Role                          50000 non-null  object
#  5   Experience_Years                  50000 non-null  int64
#  6   Monthly_Salary_INR                50000 non-null  float64
#  7   Working_Hours_per_Week            50000 non-null  int64
#  8   Commute_Time_Hours                50000 non-null  float64
#  9   Remote_Work                       50000 non-null  bool
#  10  Stress_Level                      50000 non-null  int64
# ...

# %%
df1 = df.copy()

# %%
# remove unwanted columns
df1 = df1.drop(columns=['ID','Location','Discrimination_Experienced','Gender_Bias_Experienced','Training_Opportunities','Company_Size'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               50000 non-null  int64
#  1   Gender                            50000 non-null  object
#  2   Marital_Status                    50000 non-null  object
#  3   Job_Role                          50000 non-null  object
#  4   Experience_Years                  50000 non-null  int64
#  5   Monthly_Salary_INR                50000 non-null  float64
#  6   Working_Hours_per_Week            50000 non-null  int64
#  7   Commute_Time_Hours                50000 non-null  float64
#  8   Remote_Work                       50000 non-null  bool
#  9   Stress_Level                      50000 non-null  int64
#  10  Health_Issues                     37459 non-null  object
# ...

# %%
df1.head()
# Out:
#    Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   56  Non-Binary        Widowed  Developer                 5
# 1   46      Female         Single    Analyst                20
# 2   32      Female         Single  Developer                10
# 3   60      Female       Divorced    Analyst                26
# 4   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  Stress_Level  ... Mental_Health_Leave_Taken  \
# 0         True             0  ...                     False
# 1         True             7  ...                      True
# ...

# %%
# display all columns, previously it not display few columns
pd.set_option("display.max_columns", None)

# %%
df1.head()
# Out:
#    Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   56  Non-Binary        Widowed  Developer                 5
# 1   46      Female         Single    Analyst                20
# 2   32      Female         Single  Developer                10
# 3   60      Female       Divorced    Analyst                26
# 4   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  Stress_Level Health_Issues Department  Sleep_Hours  \
# 0         True             0           NaN  Marketing          5.6
# ...

# %%
# find unique values in the column Health_Issues
df1['Health_Issues'].unique()
# Out:
# array([nan, 'Physical', 'Mental', 'Both'], dtype=object)

# %%
# find unique values in the column Health_Issues
df['Burnout_Symptoms'].unique()
# Out:
# array(['No', 'Yes', 'Occasional'], dtype=object)

# %%
df1 = df1.drop(columns=['Performance_Rating','Department'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               50000 non-null  int64
#  1   Gender                            50000 non-null  object
#  2   Marital_Status                    50000 non-null  object
#  3   Job_Role                          50000 non-null  object
#  4   Experience_Years                  50000 non-null  int64
#  5   Monthly_Salary_INR                50000 non-null  float64
#  6   Working_Hours_per_Week            50000 non-null  int64
#  7   Commute_Time_Hours                50000 non-null  float64
#  8   Remote_Work                       50000 non-null  bool
#  9   Stress_Level                      50000 non-null  int64
#  10  Health_Issues                     37459 non-null  object
# ...

# %%
df1['Health_Issues'].unique()
# Out:
# array([nan, 'Physical', 'Mental', 'Both'], dtype=object)

# %%
# fill the Stress level with new value
df1['Health_Issues'].fillna("N/A", inplace=True)
# Out:
# <ipython-input-20-27ba388912e0>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Health_Issues'].fillna("N/A", inplace=True)

# %%
df1['Health_Issues'].unique()
# Out:
# array(['N/A', 'Physical', 'Mental', 'Both'], dtype=object)

# %%
print(df1['Health_Issues'].dtype)
# Out:
# object

# %%
# print 5 data in the middle random index
df1.sample(5)
# Out:
#        Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 48746   52  Non-Binary        Married    Analyst                25
# 40072   59  Non-Binary         Single         HR                 6
# 2142    63      Female         Single  Developer                20
# 47702   40        Male        Married         HR                 4
# 890     25      Female       Divorced    Manager                13
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 48746           156475.92                      49                0.52
# 40072            24306.28                      58                2.81
# 2142             46290.33                      75                2.13
# 47702            64723.98                      67                0.84
# 890             123799.44                      83                1.77
#
#        Remote_Work  Stress_Level Health_Issues  Sleep_Hours  \
# 48746        False             1        Mental          6.1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               50000 non-null  int64
#  1   Gender                            50000 non-null  object
#  2   Marital_Status                    50000 non-null  object
#  3   Job_Role                          50000 non-null  object
#  4   Experience_Years                  50000 non-null  int64
#  5   Monthly_Salary_INR                50000 non-null  float64
#  6   Working_Hours_per_Week            50000 non-null  int64
#  7   Commute_Time_Hours                50000 non-null  float64
#  8   Remote_Work                       50000 non-null  bool
#  9   Stress_Level                      50000 non-null  int64
#  10  Health_Issues                     50000 non-null  object
# ...

# %% [markdown]
# # Label Encoding to convert the object into int

# %% [markdown]
# 1. First check the unique values of object featuresHealth_Issues

# %%
df1['Gender'].unique()
# Out:
# array(['Non-Binary', 'Female', 'Male'], dtype=object)

# %%
df1['Marital_Status'].unique()
# Out:
# array(['Widowed', 'Single', 'Divorced', 'Married'], dtype=object)

# %%
df1['Job_Role'].unique()
# Out:
# array(['Developer', 'Analyst', 'Sales', 'Manager', 'HR', 'Support'],
#       dtype=object)

# %%
df1['Health_Issues'].unique()
# Out:
# array(['N/A', 'Physical', 'Mental', 'Both'], dtype=object)

# %%
df1['Burnout_Symptoms'].unique()
# Out:
# array(['No', 'Yes', 'Occasional'], dtype=object)

# %% [markdown]
# 2. Label encode the each feature

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1['Gender'] = le.fit_transform(df1['Gender'])

# %%
df1['Marital_Status'] =  le.fit_transform(df1['Marital_Status'])

# %%
df1['Job_Role'] = le.fit_transform(df1['Job_Role'])

# %%
df1['Health_Issues'] = le.fit_transform(df1['Health_Issues'])

# %%
df1['Burnout_Symptoms'] = le.fit_transform(df1['Burnout_Symptoms'])

# %%
df1['Mental_Health_Leave_Taken'] = le.fit_transform(df1['Mental_Health_Leave_Taken'])

# %%
df1['Remote_Work'] = le.fit_transform(df1['Remote_Work'])

# %% [markdown]
# 3. Verify the datatype using info()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               50000 non-null  int64
#  1   Gender                            50000 non-null  int64
#  2   Marital_Status                    50000 non-null  int64
#  3   Job_Role                          50000 non-null  int64
#  4   Experience_Years                  50000 non-null  int64
#  5   Monthly_Salary_INR                50000 non-null  float64
#  6   Working_Hours_per_Week            50000 non-null  int64
#  7   Commute_Time_Hours                50000 non-null  float64
#  8   Remote_Work                       50000 non-null  int64
#  9   Stress_Level                      50000 non-null  int64
#  10  Health_Issues                     50000 non-null  int64
# ...

# %%
df1Copy = df1.copy()

# %%
df1.head()
# Out:
#    Age  Gender  Marital_Status  Job_Role  Experience_Years  \
# 0   56       2               3         1                 5
# 1   46       0               2         0                20
# 2   32       0               2         1                10
# 3   60       0               0         0                26
# 4   25       1               1         4                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  Stress_Level  Health_Issues  Sleep_Hours  \
# 0            1             0              2          5.6
# 1            1             7              2          9.0
# ...

# %% [markdown]
# # X, Y split

# %%
x = df1.iloc[:,:-1]
y = df1.iloc[:,-1]

# %%
x
# Out:
#        Age  Gender  Marital_Status  Job_Role  Experience_Years  \
# 0       56       2               3         1                 5
# 1       46       0               2         0                20
# 2       32       0               2         1                10
# 3       60       0               0         0                26
# 4       25       1               1         4                29
# ...    ...     ...             ...       ...               ...
# 49995   43       0               3         2                 8
# 49996   45       1               2         0                31
# 49997   43       0               0         3                 7
# 49998   62       1               1         2                 9
# 49999   19       0               0         3                 0
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0               102703.08                      44                1.72
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        2
# 3        2
# 4        0
#         ..
# 49995    0
# 49996    1
# 49997    0
# 49998    2
# 49999    0
# Name: Burnout_Symptoms, Length: 50000, dtype: int64

# %%
# Count the occurrences of each unique value
counts = y.value_counts()

# Print the counts
for value, count in counts.items():
    print(f"{value} - {count}")
# Out:
# 1 - 16677
# 0 - 16662
# 2 - 16661

# %% [markdown]
# # Test train split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=3433)

# %% [markdown]
# # KNN, SVM and Logistical regresssion
#
# > Add blockquote

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
knnModel = KNeighborsClassifier(n_neighbors=5)

# %%
knnModel.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knnModel.predict(x_test)

# %% [markdown]
# # 2. SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.datasets import make_classification

# %%
svmModel = SVC()

# %%
svmModel.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred_svm = svmModel.predict(x_test)

# %% [markdown]
# # 3. Logical regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logrModel = LogisticRegression()

# %%
logrModel.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_logr = logrModel.predict(x_test)

# %% [markdown]
# # Confusion matrix comparision for KNN, SVM and Logical regression

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm_knn = confusion_matrix(y_test, y_pred_knn)

# %%
cm_knn
# Out:
# array([[2179, 1718, 1059],
#        [2272, 1670, 1048],
#        [2284, 1725, 1045]])

# %%
cm_svm = confusion_matrix(y_test, y_pred_svm)

# %%
cm_logr = confusion_matrix(y_test, y_pred_logr)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns



# Define the labels for the confusion matrices
labels = ['YES', 'NO','Occasional']

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot the first confusion matrix
sns.heatmap(cm_knn, ax=axs[0], annot=True, cmap='Blues', fmt='d')
axs[0].set_title('1. KNN')
axs[0].set_xlabel('Predicted Labels')
axs[0].set_ylabel('True Labels')
axs[0].set_xticks([0, 1,2])
axs[0].set_yticks([0, 1,2])
axs[0].set_xticklabels(labels)
axs[0].set_yticklabels(labels)

# Plot the second confusion matrix
sns.heatmap(cm_svm, ax=axs[1], annot=True, cmap='Blues', fmt='d')
axs[1].set_title('2. SVM')
axs[1].set_xlabel('Predicted Labels')
axs[1].set_ylabel('True Labels')
axs[1].set_xticks([0, 1,2])
axs[1].set_yticks([0, 1,2])
axs[1].set_xticklabels(labels)
axs[1].set_yticklabels(labels)

# Plot the third confusion matrix
sns.heatmap(cm_logr, ax=axs[2], annot=True, cmap='Blues', fmt='d')
axs[2].set_title('3. Logical Regression')
axs[2].set_xlabel('Predicted Labels')
axs[2].set_ylabel('True Labels')
axs[2].set_xticks([0, 1,2])
axs[2].set_yticks([0, 1,2])
axs[2].set_xticklabels(labels)
axs[2].set_yticklabels(labels)

# Layout so plots do not overlap
fig.tight_layout()

plt.show()

# %% [markdown]
# # Normalize the data

# %%
from sklearn import preprocessing
norm_x = preprocessing.normalize(x)

# %%
x_l1norm = preprocessing.normalize(x, norm='l1')

# %%
x_l2norm = preprocessing.normalize(x, norm='l2')

# %%
norm_x
# Out:
# array([[5.45260976e-04, 1.94736063e-05, 2.92104094e-05, ...,
#         1.94736063e-05, 4.86840157e-05, 3.69998519e-04],
#        [2.77804713e-04, 0.00000000e+00, 1.20784658e-05, ...,
#         6.03923289e-06, 6.03923289e-05, 4.34824768e-04],
#        [8.41982153e-04, 0.00000000e+00, 5.26238845e-05, ...,
#         2.63119423e-05, 2.63119423e-05, 1.76290013e-03],
#        ...,
#        [3.91569249e-04, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 9.10626162e-05, 5.09950650e-04],
#        [8.27565949e-04, 1.33478379e-05, 1.33478379e-05, ...,
#         5.33913516e-05, 2.66956758e-05, 6.67391894e-04],
#        [5.97796351e-04, 0.00000000e+00, 0.00000000e+00, ...,
#         1.88777795e-04, 1.88777795e-04, 1.57314829e-03]])

# %%
x_train_normal,x_test_normal,y_train_normal,y_test_normal = train_test_split(norm_x,y,test_size=0.3, random_state=3)

# %%
x_train_normal_l1,x_test_normal_l1,y_train_normal_l1,y_test_normal_l1 = train_test_split(x_l1norm,y,test_size=0.3, random_state=3)

# %%
x_train_normal_l2,x_test_normal_l2,y_train_normal_l2,y_test_normal_l2 = train_test_split(x_l2norm,y,test_size=0.3, random_state=3)

# %%
x_train.shape
# Out:
# (35000, 21)

# %%
x_test
# Out:
#        Age  Gender  Marital_Status  Job_Role  Experience_Years  \
# 48465   61       1               3         3                 6
# 2463    19       1               3         0                20
# 3851    21       2               2         1                33
# 1860    25       1               3         3                21
# 3227    51       1               0         4                25
# ...    ...     ...             ...       ...               ...
# 2855    27       0               1         1                 0
# 48716   60       0               0         3                38
# 23999   47       2               0         1                40
# 34679   47       2               0         0                29
# 4394    34       2               3         1                23
#
#        Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 48465           122089.55                      84                2.95
# ...

# %% [markdown]
# # KNN, SVM and Logistical regresssion with Normalized data

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
knnModel1 = KNeighborsClassifier(n_neighbors=5)
knnModel2 = KNeighborsClassifier(n_neighbors=5)
knnModel3 = KNeighborsClassifier(n_neighbors=5)

# %%
knnModel1.fit(x_train_normal,y_train_normal)
knnModel2.fit(x_train_normal_l1,y_train_normal_l1)
knnModel3.fit(x_train_normal_l2,y_train_normal_l2)
# Out:
# KNeighborsClassifier()

# %%
knnModel1.fit(x_train_normal,y_train_normal)
knnModel2.fit(x_train_normal_l1,y_train_normal_l1)
knnModel3.fit(x_train_normal_l2,y_train_normal_l2)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn_normal = knnModel1.predict(x_test_normal)
y_pred_knn_normal_l1 = knnModel2.predict(x_test_normal_l1)
y_pred_knn_normal_l2 = knnModel3.predict(x_test_normal_l2)

# %% [markdown]
# # 2. SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.datasets import make_classification

# %%
svmModel1 = SVC()
svmModel2 = SVC()
svmModel3 = SVC()

# %%
svmModel1.fit(x_train_normal,y_train_normal)
svmModel2.fit(x_train_normal_l1,y_train_normal_l1)
svmModel3.fit(x_train_normal_l2,y_train_normal_l2)
# Out:
# SVC()

# %%
y_pred_svm_normal = svmModel1.predict(x_test_normal)
y_pred_svm_normal_l1 = svmModel2.predict(x_test_normal_l1)
y_pred_svm_normal_l2 = svmModel3.predict(x_test_normal_l2)

# %% [markdown]
# # 3. Logical regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logrModel1 = LogisticRegression()
logrModel2 = LogisticRegression()
logrModel3 = LogisticRegression()

# %%
logrModel1.fit(x_train_normal,y_train_normal)
logrModel2.fit(x_train_normal_l1,y_train_normal_l1)
logrModel3.fit(x_train_normal_l2,y_train_normal_l2)
# Out:
# LogisticRegression()

# %%
y_pred_logr_normal = logrModel1.predict(x_test_normal)
y_pred_logr_normal_l1 = logrModel2.predict(x_test_normal_l1)
y_pred_logr_normal_l2 = logrModel3.predict(x_test_normal_l2)

# %%
cm_knn_normal = confusion_matrix(y_test_normal, y_pred_knn_normal)
cm_svm_normal = confusion_matrix(y_test_normal, y_pred_svm_normal)
cm_logr_normal = confusion_matrix(y_test_normal, y_pred_logr_normal)

# %%
cm_knn_normal_l1 = confusion_matrix(y_test_normal_l1, y_pred_knn_normal_l1)
cm_svm_normal_l1 = confusion_matrix(y_test_normal_l1, y_pred_svm_normal_l1)
cm_logr_normal_l1 = confusion_matrix(y_test_normal_l1, y_pred_logr_normal_l1)

# %%
cm_knn_normal_l2 = confusion_matrix(y_test_normal_l2, y_pred_knn_normal_l2)
cm_svm_normal_l2 = confusion_matrix(y_test_normal_l2, y_pred_svm_normal_l2)
cm_logr_normal_l2 = confusion_matrix(y_test_normal_l2, y_pred_logr_normal_l2)

# %%
# Define the labels for the confusion matrices
labels = ['YES', 'NO','Occasional']

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot the first confusion matrix
sns.heatmap(cm_knn_normal, ax=axs[0], annot=True, cmap='Blues', fmt='d')
axs[0].set_title('1. KNN Normalized')
axs[0].set_xlabel('Predicted Labels')
axs[0].set_ylabel('True Labels')
axs[0].set_xticks([0, 1,2])
axs[0].set_yticks([0, 1,2])
axs[0].set_xticklabels(labels)
axs[0].set_yticklabels(labels)

# Plot the second confusion matrix
sns.heatmap(cm_svm_normal, ax=axs[1], annot=True, cmap='Blues', fmt='d')
axs[1].set_title('2. SVM Normalized')
axs[1].set_xlabel('Predicted Labels')
axs[1].set_ylabel('True Labels')
axs[1].set_xticks([0, 1,2])
axs[1].set_yticks([0, 1,2])
axs[1].set_xticklabels(labels)
axs[1].set_yticklabels(labels)

# Plot the third confusion matrix
sns.heatmap(cm_logr_normal, ax=axs[2], annot=True, cmap='Blues', fmt='d')
axs[2].set_title('3. Logical Regression Normalized')
axs[2].set_xlabel('Predicted Labels')
axs[2].set_ylabel('True Labels')
axs[2].set_xticks([0, 1,2])
axs[2].set_yticks([0, 1,2])
axs[2].set_xticklabels(labels)
axs[2].set_yticklabels(labels)

# Layout so plots do not overlap
fig.tight_layout()

plt.show()

# %%
# Define the labels for the confusion matrices
labels = ['YES', 'NO','Occasional']

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot the first confusion matrix
sns.heatmap(cm_knn_normal_l1, ax=axs[0], annot=True, cmap='Blues', fmt='d')
axs[0].set_title('1. KNN Normalized L1')
axs[0].set_xlabel('Predicted Labels')
axs[0].set_ylabel('True Labels')
axs[0].set_xticks([0, 1,2])
axs[0].set_yticks([0, 1,2])
axs[0].set_xticklabels(labels)
axs[0].set_yticklabels(labels)

# Plot the second confusion matrix
sns.heatmap(cm_svm_normal_l1, ax=axs[1], annot=True, cmap='Blues', fmt='d')
axs[1].set_title('2. SVM Normalized L1')
axs[1].set_xlabel('Predicted Labels')
axs[1].set_ylabel('True Labels')
axs[1].set_xticks([0, 1,2])
axs[1].set_yticks([0, 1,2])
axs[1].set_xticklabels(labels)
axs[1].set_yticklabels(labels)

# Plot the third confusion matrix
sns.heatmap(cm_logr_normal_l1, ax=axs[2], annot=True, cmap='Blues', fmt='d')
axs[2].set_title('3. Logical Regression Normalized L1')
axs[2].set_xlabel('Predicted Labels')
axs[2].set_ylabel('True Labels')
axs[2].set_xticks([0, 1,2])
axs[2].set_yticks([0, 1,2])
axs[2].set_xticklabels(labels)
axs[2].set_yticklabels(labels)

# Layout so plots do not overlap
fig.tight_layout()

plt.show()

# %%
# Define the labels for the confusion matrices
labels = ['YES', 'NO','Occasional']

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot the first confusion matrix
sns.heatmap(cm_knn_normal_l2, ax=axs[0], annot=True, cmap='Blues', fmt='d')
axs[0].set_title('1. KNN Normalized L2')
axs[0].set_xlabel('Predicted Labels')
axs[0].set_ylabel('True Labels')
axs[0].set_xticks([0, 1,2])
axs[0].set_yticks([0, 1,2])
axs[0].set_xticklabels(labels)
axs[0].set_yticklabels(labels)

# Plot the second confusion matrix
sns.heatmap(cm_svm_normal_l2, ax=axs[1], annot=True, cmap='Blues', fmt='d')
axs[1].set_title('2. SVM Normalized L2')
axs[1].set_xlabel('Predicted Labels')
axs[1].set_ylabel('True Labels')
axs[1].set_xticks([0, 1,2])
axs[1].set_yticks([0, 1,2])
axs[1].set_xticklabels(labels)
axs[1].set_yticklabels(labels)

# Plot the third confusion matrix
sns.heatmap(cm_logr_normal_l2, ax=axs[2], annot=True, cmap='Blues', fmt='d')
axs[2].set_title('3. Logical Regression Normalized L2')
axs[2].set_xlabel('Predicted Labels')
axs[2].set_ylabel('True Labels')
axs[2].set_xticks([0, 1,2])
axs[2].set_yticks([0, 1,2])
axs[2].set_xticklabels(labels)
axs[2].set_yticklabels(labels)

# Layout so plots do not overlap
fig.tight_layout()

plt.show()
