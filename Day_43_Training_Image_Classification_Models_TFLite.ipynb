# %% [markdown]
# <a href="https://colab.research.google.com/github/rranjithkumar100/AI-Training/blob/main/Day_43_Training_Image_Classification_Models_TFLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
# !pip install --upgrade pip
# !pip install mediapipe-model-maker
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.1.1)
# Requirement already satisfied: mediapipe-model-maker in /usr/local/lib/python3.11/dist-packages (0.2.1.4)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (1.4.0)
# Requirement already satisfied: mediapipe>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (0.10.21)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (4.11.0.86)
# Requirement already satisfied: tensorflow<2.16,>=2.10 in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (2.15.1)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (0.23.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (4.9.9)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization<0.8.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (0.7.5)
# Requirement already satisfied: tensorflow-text in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (2.15.0)
# Requirement already satisfied: tf-models-official<2.16.0,>=2.13.2 in /usr/local/lib/python3.11/dist-packages (from mediapipe-model-maker) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (1.72.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.6.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-model-optimization<0.8.0->mediapipe-model-maker) (0.1.9)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization<0.8.0->mediapipe-model-maker) (25.3.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (3.0.12)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (11.2.1)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2.171.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (4.2.1)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.7.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (3.10.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (4.11.0.86)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2.2.2)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (9.0.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2.0.9)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (6.0.2)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2.5.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.15.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.2.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.2.2)
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.10->mediapipe-model-maker) (0.45.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2.25.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.26.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.6.7->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (3.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle>=1.3.9->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (6.2.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle>=1.3.9->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle>=1.3.9->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (8.0.4)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle>=1.3.9->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle>=1.3.9->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (4.67.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle>=1.3.9->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.5.1)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe>=0.10.0->mediapipe-model-maker) (0.4.34)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe>=0.10.0->mediapipe-model-maker) (0.4.34)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe>=0.10.0->mediapipe-model-maker) (4.11.0.86)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from mediapipe>=0.10.0->mediapipe-model-maker) (0.5.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.22.0->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.22.0->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.2.2)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe>=0.10.0->mediapipe-model-maker) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe>=0.10.0->mediapipe-model-maker) (2.22)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-hub->mediapipe-model-maker) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.10->mediapipe-model-maker) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.4.8)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from sacrebleu->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (3.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (5.4.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.11/dist-packages (from seqeval->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official<2.16.0,>=2.13.2->mediapipe-model-maker) (3.6.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons->mediapipe-model-maker) (2.13.3)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->mediapipe-model-maker) (0.7.2)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->mediapipe-model-maker) (1.12.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->mediapipe-model-maker) (2.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->mediapipe-model-maker) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->mediapipe-model-maker) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->mediapipe-model-maker) (1.17.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets->mediapipe-model-maker) (0.10.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->mediapipe-model-maker) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->mediapipe-model-maker) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->mediapipe-model-maker) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->mediapipe-model-maker) (3.22.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets->mediapipe-model-maker) (0.16)

# %%
from google.colab import files
import os
import tensorflow as tf
assert tf.__version__.startswith('2')

from mediapipe_model_maker import image_classifier

import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.11/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ## Loading Dataset

# %%
#save final weights to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_file_name = "/content/drive/MyDrive/AI/FruitsDataSet/fruits_dataset" #@param {type:"string"}
# !unzip {zip_file_name}.zip
# Out:
# Archive:  /content/drive/MyDrive/AI/FruitsDataSet/fruits_dataset.zip
#    creating: dataset/
#    creating: dataset/apple/
#   inflating: dataset/apple/Image_1.jpg
#   inflating: dataset/apple/Image_10.jpg
#   inflating: dataset/apple/Image_16.jpg
#   inflating: dataset/apple/Image_17.jpg
#   inflating: dataset/apple/Image_18.jpg
#   inflating: dataset/apple/Image_19.jpg
#   inflating: dataset/apple/Image_2.jpg
#   inflating: dataset/apple/Image_20.jpg
#   inflating: dataset/apple/Image_21.jpg
#   inflating: dataset/apple/Image_23.jpg
#   inflating: dataset/apple/Image_24.jpg
#   inflating: dataset/apple/Image_25.jpg
#   inflating: dataset/apple/Image_26.jpg
#   inflating: dataset/apple/Image_27.jpg
#   inflating: dataset/apple/Image_28.jpg
#   inflating: dataset/apple/Image_3.jpg
#   inflating: dataset/apple/Image_31.jpg
#   inflating: dataset/apple/Image_32.jpg
#   inflating: dataset/apple/Image_33.jpg
#   inflating: dataset/apple/Image_34.jpg
#   inflating: dataset/apple/Image_35.png
#   inflating: dataset/apple/Image_36.jpg
#   inflating: dataset/apple/Image_37.jpg
#   inflating: dataset/apple/Image_38.jpg
#   inflating: dataset/apple/Image_39.jpg
#   inflating: dataset/apple/Image_4.jpg
#   inflating: dataset/apple/Image_40.jpg
#   inflating: dataset/apple/Image_41.jpg
#   inflating: dataset/apple/Image_42.jpg
#   inflating: dataset/apple/Image_43.jpg
#   inflating: dataset/apple/Image_44.jpg
#   inflating: dataset/apple/Image_45.jpg
#   inflating: dataset/apple/Image_47.jpg
#   inflating: dataset/apple/Image_48.jpg
#   inflating: dataset/apple/Image_49.jpg
#   inflating: dataset/apple/Image_5.JPG
#   inflating: dataset/apple/Image_50.jpg
#   inflating: dataset/apple/Image_51.jpg
#   inflating: dataset/apple/Image_52.jpg
#   inflating: dataset/apple/Image_53.png
#   inflating: dataset/apple/Image_54.jpg
#   inflating: dataset/apple/Image_55.jpg
#   inflating: dataset/apple/Image_56.jpg
#   inflating: dataset/apple/Image_57.jpg
#   inflating: dataset/apple/Image_58.jpg
#   inflating: dataset/apple/Image_59.png
#   inflating: dataset/apple/Image_6.jpg
#   inflating: dataset/apple/Image_60.jpg
#   inflating: dataset/apple/Image_61.jpg
#   inflating: dataset/apple/Image_62.jpg
#   inflating: dataset/apple/Image_63.jpg
#   inflating: dataset/apple/Image_64.jpg
#   inflating: dataset/apple/Image_65.png
#   inflating: dataset/apple/Image_67.jpg
#   inflating: dataset/apple/Image_68.jpg
#   inflating: dataset/apple/Image_69.jpg
#   inflating: dataset/apple/Image_7.jpg
#   inflating: dataset/apple/Image_71.png
#   inflating: dataset/apple/Image_76.png
#   inflating: dataset/apple/Image_78.jpg
#   inflating: dataset/apple/Image_8.jpg
#   inflating: dataset/apple/Image_80.jpg
#   inflating: dataset/apple/Image_81.png
#   inflating: dataset/apple/Image_82.jpg
#   inflating: dataset/apple/Image_83.png
#   inflating: dataset/apple/Image_86.jpg
#   inflating: dataset/apple/Image_87.jpg
#   inflating: dataset/apple/Image_9.jpg
#   inflating: dataset/apple/Image_90.jpg
#   inflating: dataset/apple/Image_92.png
#    creating: dataset/banana/
#   inflating: dataset/banana/Image_1.jpg
#   inflating: dataset/banana/Image_100.jpg
#   inflating: dataset/banana/Image_11.png
#   inflating: dataset/banana/Image_13.jpg
#   inflating: dataset/banana/Image_14.jpg
#   inflating: dataset/banana/Image_15.jpg
#   inflating: dataset/banana/Image_16.jpg
#   inflating: dataset/banana/Image_21.JPG
#   inflating: dataset/banana/Image_23.jpg
#   inflating: dataset/banana/Image_24.jpg
#   inflating: dataset/banana/Image_25.jpg
#   inflating: dataset/banana/Image_27.jpg
#   inflating: dataset/banana/Image_28.jpg
#   inflating: dataset/banana/Image_3.jpg
#   inflating: dataset/banana/Image_31.jpg
#   inflating: dataset/banana/Image_32.jpg
#   inflating: dataset/banana/Image_37.jpg
#   inflating: dataset/banana/Image_4.jpg
#   inflating: dataset/banana/Image_40.jpg
#   inflating: dataset/banana/Image_41.jpg
#   inflating: dataset/banana/Image_42.jpg
#   inflating: dataset/banana/Image_43.png
#   inflating: dataset/banana/Image_44.jpg
#   inflating: dataset/banana/Image_45.jpg
#   inflating: dataset/banana/Image_46.jpg
#   inflating: dataset/banana/Image_47.jpg
#   inflating: dataset/banana/Image_48.png
#   inflating: dataset/banana/Image_49.jpg
#   inflating: dataset/banana/Image_5.jpg
#   inflating: dataset/banana/Image_50.jpg
#   inflating: dataset/banana/Image_51.jpeg
#   inflating: dataset/banana/Image_52.jpg
#   inflating: dataset/banana/Image_53.png
#   inflating: dataset/banana/Image_54.jpg
#   inflating: dataset/banana/Image_55.jpg
#   inflating: dataset/banana/Image_56.jpg
#   inflating: dataset/banana/Image_57.jpg
#   inflating: dataset/banana/Image_58.png
#   inflating: dataset/banana/Image_59.jpg
#   inflating: dataset/banana/Image_6.jpg
#   inflating: dataset/banana/Image_61.png
#   inflating: dataset/banana/Image_62.jpg
#   inflating: dataset/banana/Image_63.jpg
#   inflating: dataset/banana/Image_64.jpg
#   inflating: dataset/banana/Image_65.png
#   inflating: dataset/banana/Image_66.jpg
#   inflating: dataset/banana/Image_67.jpg
#   inflating: dataset/banana/Image_68.jpg
#   inflating: dataset/banana/Image_69.jpg
#   inflating: dataset/banana/Image_71.jpg
#   inflating: dataset/banana/Image_72.jpg
#   inflating: dataset/banana/Image_73.jpg
#   inflating: dataset/banana/Image_75.jpg
#   inflating: dataset/banana/Image_76.jpg
#   inflating: dataset/banana/Image_77.jpg
#   inflating: dataset/banana/Image_79.jpg
#   inflating: dataset/banana/Image_8.jpg
#   inflating: dataset/banana/Image_80.png
#   inflating: dataset/banana/Image_81.jpeg
#   inflating: dataset/banana/Image_82.jpg
#   inflating: dataset/banana/Image_83.png
#   inflating: dataset/banana/Image_84.jpg
#   inflating: dataset/banana/Image_85.jpg
#   inflating: dataset/banana/Image_86.jpg
#   inflating: dataset/banana/Image_88.png
#   inflating: dataset/banana/Image_89.jpg
#   inflating: dataset/banana/Image_9.jpg
#   inflating: dataset/banana/Image_90.jpg
#   inflating: dataset/banana/Image_91.jpg
#   inflating: dataset/banana/Image_92.jpg
#   inflating: dataset/banana/Image_93.jpg
#   inflating: dataset/banana/Image_95.jpg
#   inflating: dataset/banana/Image_96.jpg
#   inflating: dataset/banana/Image_97.jpg
#   inflating: dataset/banana/Image_98.jpg
#    creating: dataset/lemon/
#   inflating: dataset/lemon/Image_1.png
#   inflating: dataset/lemon/Image_10.jpg
#   inflating: dataset/lemon/Image_100.png
#   inflating: dataset/lemon/Image_11.jpg
#   inflating: dataset/lemon/Image_12.jpg
#   inflating: dataset/lemon/Image_13.jpg
#   inflating: dataset/lemon/Image_14.jpg
#   inflating: dataset/lemon/Image_15.JPG
#   inflating: dataset/lemon/Image_16.jpg
#   inflating: dataset/lemon/Image_17.jpg
#   inflating: dataset/lemon/Image_18.jpg
#   inflating: dataset/lemon/Image_19.jpg
#   inflating: dataset/lemon/Image_2.jpg
#   inflating: dataset/lemon/Image_21.jpg
#   inflating: dataset/lemon/Image_22.jpg
#   inflating: dataset/lemon/Image_23.jpg
#   inflating: dataset/lemon/Image_24.jpg
#   inflating: dataset/lemon/Image_25.jpg
#   inflating: dataset/lemon/Image_27.jpg
#   inflating: dataset/lemon/Image_28.jpg
#   inflating: dataset/lemon/Image_29.jpeg
#   inflating: dataset/lemon/Image_3.jpg
#   inflating: dataset/lemon/Image_30.jpg
#   inflating: dataset/lemon/Image_31.jpg
#   inflating: dataset/lemon/Image_32.jpg
#   inflating: dataset/lemon/Image_33.jpeg
#   inflating: dataset/lemon/Image_34.jpg
#   inflating: dataset/lemon/Image_35.jpg
#   inflating: dataset/lemon/Image_36.png
#   inflating: dataset/lemon/Image_37.png
#   inflating: dataset/lemon/Image_38.jpg
#   inflating: dataset/lemon/Image_39.png
#   inflating: dataset/lemon/Image_4.jpg
#   inflating: dataset/lemon/Image_41.jpg
#   inflating: dataset/lemon/Image_42.jpg
#   inflating: dataset/lemon/Image_43.jpeg
#   inflating: dataset/lemon/Image_44.jpg
#   inflating: dataset/lemon/Image_45.png
#   inflating: dataset/lemon/Image_47.jpg
#   inflating: dataset/lemon/Image_48.jpg
#   inflating: dataset/lemon/Image_49.jpg
#   inflating: dataset/lemon/Image_5.jpg
#   inflating: dataset/lemon/Image_50.jpg
#   inflating: dataset/lemon/Image_51.jpg
#   inflating: dataset/lemon/Image_52.png
#   inflating: dataset/lemon/Image_53.jpg
#   inflating: dataset/lemon/Image_54.jpg
#   inflating: dataset/lemon/Image_55.jpg
#   inflating: dataset/lemon/Image_56.jpg
#   inflating: dataset/lemon/Image_57.jpg
#   inflating: dataset/lemon/Image_58.jpg
#   inflating: dataset/lemon/Image_6.png
#   inflating: dataset/lemon/Image_60.jpg
#   inflating: dataset/lemon/Image_61.png
#   inflating: dataset/lemon/Image_63.jpg
#   inflating: dataset/lemon/Image_64.png
#   inflating: dataset/lemon/Image_65.jpg
#   inflating: dataset/lemon/Image_69.jpg
#   inflating: dataset/lemon/Image_7.jpg
#   inflating: dataset/lemon/Image_70.jpg
#   inflating: dataset/lemon/Image_71.jpg
#   inflating: dataset/lemon/Image_74.jpg
#   inflating: dataset/lemon/Image_75.jpg
#   inflating: dataset/lemon/Image_76.jpeg
#   inflating: dataset/lemon/Image_77.jpg
#   inflating: dataset/lemon/Image_78.jpg
#   inflating: dataset/lemon/Image_8.png
#   inflating: dataset/lemon/Image_80.jpg
#   inflating: dataset/lemon/Image_84.jpg
#   inflating: dataset/lemon/Image_85.jpg
#   inflating: dataset/lemon/Image_87.png
#   inflating: dataset/lemon/Image_88.jpg
#   inflating: dataset/lemon/Image_9.jpg
#   inflating: dataset/lemon/Image_90.jpg
#   inflating: dataset/lemon/Image_92.jpg
#   inflating: dataset/lemon/Image_93.jpg
#   inflating: dataset/lemon/Image_94.jpg
#   inflating: dataset/lemon/Image_95.png
#   inflating: dataset/lemon/Image_96.jpg
#   inflating: dataset/lemon/Image_97.jpg
#   inflating: dataset/lemon/Image_98.jpg
#   inflating: dataset/lemon/Image_99.jpg
#    creating: dataset/onion/
#   inflating: dataset/onion/Image_1.jpg
#   inflating: dataset/onion/Image_10.jpg
#   inflating: dataset/onion/Image_100.jpg
#   inflating: dataset/onion/Image_11.jpg
#   inflating: dataset/onion/Image_12.jpg
#   inflating: dataset/onion/Image_13.jpg
#   inflating: dataset/onion/Image_14.jpg
#   inflating: dataset/onion/Image_15.jpg
#   inflating: dataset/onion/Image_16.jpg
#   inflating: dataset/onion/Image_17.jpg
#   inflating: dataset/onion/Image_18.jpg
#   inflating: dataset/onion/Image_19.jpg
#   inflating: dataset/onion/Image_2.jpg
#   inflating: dataset/onion/Image_20.jpg
#   inflating: dataset/onion/Image_21.jpg
#   inflating: dataset/onion/Image_22.jpg
#   inflating: dataset/onion/Image_23.jpg
#   inflating: dataset/onion/Image_24.jpg
#   inflating: dataset/onion/Image_25.jpg
#   inflating: dataset/onion/Image_26.jpg
#   inflating: dataset/onion/Image_27.jpg
#   inflating: dataset/onion/Image_28.jpg
#   inflating: dataset/onion/Image_29.jpg
#   inflating: dataset/onion/Image_3.jpg
#   inflating: dataset/onion/Image_30.jpg
#   inflating: dataset/onion/Image_31.png
#   inflating: dataset/onion/Image_32.jpg
#   inflating: dataset/onion/Image_33.png
#   inflating: dataset/onion/Image_34.png
#   inflating: dataset/onion/Image_35.png
#   inflating: dataset/onion/Image_36.jpg
#   inflating: dataset/onion/Image_37.png
#   inflating: dataset/onion/Image_38.jpg
#   inflating: dataset/onion/Image_39.jpg
#   inflating: dataset/onion/Image_4.jpg
#   inflating: dataset/onion/Image_40.jpg
#   inflating: dataset/onion/Image_41.jpg
#   inflating: dataset/onion/Image_42.JPG
#   inflating: dataset/onion/Image_43.jpg
#   inflating: dataset/onion/Image_45.jpg
#   inflating: dataset/onion/Image_46.jpg
#   inflating: dataset/onion/Image_47.jpg
#   inflating: dataset/onion/Image_48.jpg
#   inflating: dataset/onion/Image_49.png
#   inflating: dataset/onion/Image_5.jpg
#   inflating: dataset/onion/Image_50.jpg
#   inflating: dataset/onion/Image_52.jpg
#   inflating: dataset/onion/Image_53.jpg
#   inflating: dataset/onion/Image_54.jpg
#   inflating: dataset/onion/Image_55.jpg
#   inflating: dataset/onion/Image_56.jpg
#   inflating: dataset/onion/Image_58.jpg
#   inflating: dataset/onion/Image_59.jpg
#   inflating: dataset/onion/Image_6.jpg
#   inflating: dataset/onion/Image_60.jpg
#   inflating: dataset/onion/Image_61.jpg
#   inflating: dataset/onion/Image_62.jpg
#   inflating: dataset/onion/Image_63.png
#   inflating: dataset/onion/Image_64.jpeg
#   inflating: dataset/onion/Image_65.jpg
#   inflating: dataset/onion/Image_66.jpg
#   inflating: dataset/onion/Image_68.png
#   inflating: dataset/onion/Image_69.jpg
#   inflating: dataset/onion/Image_7.jpg
#   inflating: dataset/onion/Image_70.jpg
#   inflating: dataset/onion/Image_71.png
#   inflating: dataset/onion/Image_72.jpg
#   inflating: dataset/onion/Image_73.jpg
#   inflating: dataset/onion/Image_74.jpg
#   inflating: dataset/onion/Image_75.jpg
#   inflating: dataset/onion/Image_78.png
#   inflating: dataset/onion/Image_79.jpg
#   inflating: dataset/onion/Image_8.jpg
#   inflating: dataset/onion/Image_80.jpg
#   inflating: dataset/onion/Image_81.jpg
#   inflating: dataset/onion/Image_82.jpg
#   inflating: dataset/onion/Image_83.jpg
#   inflating: dataset/onion/Image_84.jpg
#   inflating: dataset/onion/Image_85.jpg
#   inflating: dataset/onion/Image_86.jpg
#   inflating: dataset/onion/Image_87.jpg
#   inflating: dataset/onion/Image_88.jpg
#   inflating: dataset/onion/Image_89.jpg
#   inflating: dataset/onion/Image_9.png
#   inflating: dataset/onion/Image_90.jpg
#   inflating: dataset/onion/Image_91.jpg
#   inflating: dataset/onion/Image_92.jpg
#   inflating: dataset/onion/Image_93.jpg
#   inflating: dataset/onion/Image_94.png
#   inflating: dataset/onion/Image_95.jpg
#   inflating: dataset/onion/Image_96.jpg
#   inflating: dataset/onion/Image_97.jpg
#   inflating: dataset/onion/Image_98.jpg
#   inflating: dataset/onion/Image_99.jpg
#    creating: dataset/potato/
#   inflating: dataset/potato/Image_1.jpg
#   inflating: dataset/potato/Image_10.jpg
#   inflating: dataset/potato/Image_100.jpg
#   inflating: dataset/potato/Image_11.jpg
#   inflating: dataset/potato/Image_12.jpg
#   inflating: dataset/potato/Image_13.jpg
#   inflating: dataset/potato/Image_14.jpg
#   inflating: dataset/potato/Image_15.jpg
#   inflating: dataset/potato/Image_16.jpg
#   inflating: dataset/potato/Image_20.jpg
#   inflating: dataset/potato/Image_22.png
#   inflating: dataset/potato/Image_23.jpg
#   inflating: dataset/potato/Image_28.jpg
#   inflating: dataset/potato/Image_29.jpg
#   inflating: dataset/potato/Image_3.jpg
#   inflating: dataset/potato/Image_30.jpeg
#   inflating: dataset/potato/Image_31.jpg
#   inflating: dataset/potato/Image_32.jpg
#   inflating: dataset/potato/Image_33.jpg
#   inflating: dataset/potato/Image_34.jpg
#   inflating: dataset/potato/Image_38.jpg
#   inflating: dataset/potato/Image_4.jpg
#   inflating: dataset/potato/Image_43.jpg
#   inflating: dataset/potato/Image_44.jpg
#   inflating: dataset/potato/Image_45.jpg
#   inflating: dataset/potato/Image_46.png
#   inflating: dataset/potato/Image_47.jpg
#   inflating: dataset/potato/Image_48.jpg
#   inflating: dataset/potato/Image_49.jpg
#   inflating: dataset/potato/Image_5.JPG
#   inflating: dataset/potato/Image_50.jpg
#   inflating: dataset/potato/Image_51.jpg
#   inflating: dataset/potato/Image_52.jpg
#   inflating: dataset/potato/Image_53.jpg
#   inflating: dataset/potato/Image_54.jpg
#   inflating: dataset/potato/Image_55.jpg
#   inflating: dataset/potato/Image_56.jpg
#   inflating: dataset/potato/Image_57.jpg
#   inflating: dataset/potato/Image_58.jpg
#   inflating: dataset/potato/Image_6.jpg
#   inflating: dataset/potato/Image_60.jpg
#   inflating: dataset/potato/Image_61.jpg
#   inflating: dataset/potato/Image_62.jpg
#   inflating: dataset/potato/Image_63.jpg
#   inflating: dataset/potato/Image_64.jpg
#   inflating: dataset/potato/Image_65.png
#   inflating: dataset/potato/Image_66.jpg
#   inflating: dataset/potato/Image_67.jpg
#   inflating: dataset/potato/Image_68.jpg
#   inflating: dataset/potato/Image_69.png
#   inflating: dataset/potato/Image_7.jpg
#   inflating: dataset/potato/Image_71.jpg
#   inflating: dataset/potato/Image_72.jpg
#   inflating: dataset/potato/Image_73.jpg
#   inflating: dataset/potato/Image_74.jpg
#   inflating: dataset/potato/Image_76.jpg
#   inflating: dataset/potato/Image_77.jpg
#   inflating: dataset/potato/Image_78.jpg
#   inflating: dataset/potato/Image_79.jpg
#   inflating: dataset/potato/Image_8.jpg
#   inflating: dataset/potato/Image_80.png
#   inflating: dataset/potato/Image_81.jpg
#   inflating: dataset/potato/Image_82.jpg
#   inflating: dataset/potato/Image_83.jpg
#   inflating: dataset/potato/Image_84.png
#   inflating: dataset/potato/Image_85.jpg
#   inflating: dataset/potato/Image_86.jpg
#   inflating: dataset/potato/Image_88.jpeg
#   inflating: dataset/potato/Image_89.jpg
#   inflating: dataset/potato/Image_90.png
#   inflating: dataset/potato/Image_91.jpg
#   inflating: dataset/potato/Image_92.jpg
#   inflating: dataset/potato/Image_94.jpg
#   inflating: dataset/potato/Image_95.jpg
#   inflating: dataset/potato/Image_97.jpg
#   inflating: dataset/potato/Image_98.jpg
#   inflating: dataset/potato/Image_99.JPG
#    creating: dataset/watermelon/
#   inflating: dataset/watermelon/Image_1.jpg
#   inflating: dataset/watermelon/Image_10.jpg
#   inflating: dataset/watermelon/Image_100.jpg
#   inflating: dataset/watermelon/Image_13.jpg
#   inflating: dataset/watermelon/Image_14.jpeg
#   inflating: dataset/watermelon/Image_15.jpg
#   inflating: dataset/watermelon/Image_16.jpg
#   inflating: dataset/watermelon/Image_17.jpg
#   inflating: dataset/watermelon/Image_18.jpg
#   inflating: dataset/watermelon/Image_19.png
#   inflating: dataset/watermelon/Image_2.jpg
#   inflating: dataset/watermelon/Image_20.jpg
#   inflating: dataset/watermelon/Image_21.jpg
#   inflating: dataset/watermelon/Image_22.jpg
#   inflating: dataset/watermelon/Image_23.jpg
#   inflating: dataset/watermelon/Image_24.jpg
#   inflating: dataset/watermelon/Image_25.jpg
#   inflating: dataset/watermelon/Image_26.jpg
#   inflating: dataset/watermelon/Image_27.jpg
#   inflating: dataset/watermelon/Image_28.jpg
#   inflating: dataset/watermelon/Image_29.jpg
#   inflating: dataset/watermelon/Image_3.jpg
#   inflating: dataset/watermelon/Image_30.jpg
#   inflating: dataset/watermelon/Image_31.JPG
#   inflating: dataset/watermelon/Image_32.jpg
#   inflating: dataset/watermelon/Image_33.png
#   inflating: dataset/watermelon/Image_34.jpg
#   inflating: dataset/watermelon/Image_35.jpg
#   inflating: dataset/watermelon/Image_36.jpg
#   inflating: dataset/watermelon/Image_37.jpg
#   inflating: dataset/watermelon/Image_38.jpg
#   inflating: dataset/watermelon/Image_39.jpg
#   inflating: dataset/watermelon/Image_4.jpg
#   inflating: dataset/watermelon/Image_40.jpg
#   inflating: dataset/watermelon/Image_41.jpg
#   inflating: dataset/watermelon/Image_42.jpg
#   inflating: dataset/watermelon/Image_43.jpg
#   inflating: dataset/watermelon/Image_44.jpg
#   inflating: dataset/watermelon/Image_45.jpg
#   inflating: dataset/watermelon/Image_46.jpg
#   inflating: dataset/watermelon/Image_47.jpg
#   inflating: dataset/watermelon/Image_49.jpg
#   inflating: dataset/watermelon/Image_5.jpg
#   inflating: dataset/watermelon/Image_50.jpg
#   inflating: dataset/watermelon/Image_51.jpg
#   inflating: dataset/watermelon/Image_52.jpg
#   inflating: dataset/watermelon/Image_53.jpg
#   inflating: dataset/watermelon/Image_55.jpg
#   inflating: dataset/watermelon/Image_56.jpg
#   inflating: dataset/watermelon/Image_57.jpg
#   inflating: dataset/watermelon/Image_58.jpg
#   inflating: dataset/watermelon/Image_59.jpg
#   inflating: dataset/watermelon/Image_6.jpg
#   inflating: dataset/watermelon/Image_61.jpg
#   inflating: dataset/watermelon/Image_62.jpg
#   inflating: dataset/watermelon/Image_63.jpg
#   inflating: dataset/watermelon/Image_65.jpg
#   inflating: dataset/watermelon/Image_66.jpg
#   inflating: dataset/watermelon/Image_67.jpg
#   inflating: dataset/watermelon/Image_68.jpg
#   inflating: dataset/watermelon/Image_69.jpg
#   inflating: dataset/watermelon/Image_7.jpg
#   inflating: dataset/watermelon/Image_70.jpg
#   inflating: dataset/watermelon/Image_73.jpg
#   inflating: dataset/watermelon/Image_78.jpg
#   inflating: dataset/watermelon/Image_79.jpg
#   inflating: dataset/watermelon/Image_8.jpg
#   inflating: dataset/watermelon/Image_81.jpg
#   inflating: dataset/watermelon/Image_83.jpg
#   inflating: dataset/watermelon/Image_84.jpg
#   inflating: dataset/watermelon/Image_85.jpg
#   inflating: dataset/watermelon/Image_86.jpg
#   inflating: dataset/watermelon/Image_88.jpg
#   inflating: dataset/watermelon/Image_89.png
#   inflating: dataset/watermelon/Image_9.jpg
#   inflating: dataset/watermelon/Image_90.jpg
#   inflating: dataset/watermelon/Image_91.jpg
#   inflating: dataset/watermelon/Image_92.jpg
#   inflating: dataset/watermelon/Image_94.jpg
#   inflating: dataset/watermelon/Image_95.jpg
#   inflating: dataset/watermelon/Image_96.jpg
#   inflating: dataset/watermelon/Image_97.jpg
#   inflating: dataset/watermelon/Image_98.jpg
#   inflating: dataset/watermelon/Image_99.jpg

# %%
image_path = '/content/dataset'

# %%
print(image_path)
labels = []
for i in os.listdir(image_path):
  if os.path.isdir(os.path.join(image_path, i)):
    labels.append(i)
print(labels)
# Out:
# /content/dataset
# ['banana', 'onion', 'watermelon', 'apple', 'lemon', 'potato']

# %%
NUM_EXAMPLES = 5

for label in labels:
  label_dir = os.path.join(image_path, label)
  example_filenames = os.listdir(label_dir)[:NUM_EXAMPLES]
  fig, axs = plt.subplots(1, NUM_EXAMPLES, figsize=(10,2))
  for i in range(NUM_EXAMPLES):
    axs[i].imshow(plt.imread(os.path.join(label_dir, example_filenames[i])))
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False)
  fig.suptitle(f'Showing {NUM_EXAMPLES} examples for {label}')

plt.show()

# %%
data = image_classifier.Dataset.from_folder(image_path)
train_data, remaining_data = data.split(0.9)
test_data, validation_data = remaining_data.split(0.5)

# %% [markdown]
# ## Model Training

# %%
spec = image_classifier.SupportedModels.EFFICIENTNET_LITE2
hparams = image_classifier.HParams(export_dir="exported_model",epochs=50)
options = image_classifier.ImageClassifierOptions(supported_model=spec, hparams=hparams)

# %%
model = image_classifier.ImageClassifier.create(
    train_data = train_data,
    validation_data = validation_data,
    options=options,
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              4869168
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 6)                 7686
#
# =================================================================
# Total params: 4876854 (18.60 MB)
# Trainable params: 7686 (30.02 KB)
# Non-trainable params: 4869168 (18.57 MB)
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py:1260: resize_bicubic (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BICUBIC...)` instead.
# Epoch 1/50
# 216/216 [==============================] - 68s 290ms/step - loss: 1.8808 - accuracy: 0.1782 - val_loss: 1.6832 - val_accuracy: 0.3200
# Epoch 2/50
# 216/216 [==============================] - 63s 290ms/step - loss: 1.7207 - accuracy: 0.2870 - val_loss: 1.5432 - val_accuracy: 0.4000
# Epoch 3/50
# 216/216 [==============================] - 61s 283ms/step - loss: 1.5025 - accuracy: 0.5324 - val_loss: 1.3679 - val_accuracy: 0.6400
# Epoch 4/50
# 216/216 [==============================] - 61s 281ms/step - loss: 1.2636 - accuracy: 0.7407 - val_loss: 1.2152 - val_accuracy: 0.8400
# Epoch 5/50
# 216/216 [==============================] - 62s 285ms/step - loss: 1.0992 - accuracy: 0.8495 - val_loss: 1.0751 - val_accuracy: 0.8800
# Epoch 6/50
# 216/216 [==============================] - 56s 257ms/step - loss: 0.9760 - accuracy: 0.8611 - val_loss: 0.9660 - val_accuracy: 0.9200
# Epoch 7/50
# 216/216 [==============================] - 57s 262ms/step - loss: 0.8681 - accuracy: 0.9074 - val_loss: 0.8812 - val_accuracy: 0.9200
# Epoch 8/50
# 216/216 [==============================] - 62s 287ms/step - loss: 0.7803 - accuracy: 0.9491 - val_loss: 0.8109 - val_accuracy: 0.9600
# Epoch 9/50
# 216/216 [==============================] - 62s 289ms/step - loss: 0.7364 - accuracy: 0.9329 - val_loss: 0.7617 - val_accuracy: 0.9600
# Epoch 10/50
# 216/216 [==============================] - 62s 288ms/step - loss: 0.6974 - accuracy: 0.9375 - val_loss: 0.7187 - val_accuracy: 0.9600
# Epoch 11/50
# 216/216 [==============================] - 56s 261ms/step - loss: 0.6731 - accuracy: 0.9444 - val_loss: 0.6889 - val_accuracy: 0.9600
# Epoch 12/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.6497 - accuracy: 0.9398 - val_loss: 0.6665 - val_accuracy: 0.9600
# Epoch 13/50
# 216/216 [==============================] - 61s 283ms/step - loss: 0.6279 - accuracy: 0.9491 - val_loss: 0.6497 - val_accuracy: 0.9600
# Epoch 14/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.6101 - accuracy: 0.9583 - val_loss: 0.6322 - val_accuracy: 0.9600
# Epoch 15/50
# 216/216 [==============================] - 67s 308ms/step - loss: 0.5991 - accuracy: 0.9606 - val_loss: 0.6134 - val_accuracy: 0.9600
# Epoch 16/50
# 216/216 [==============================] - 55s 255ms/step - loss: 0.5803 - accuracy: 0.9653 - val_loss: 0.6069 - val_accuracy: 0.9600
# Epoch 17/50
# 216/216 [==============================] - 60s 279ms/step - loss: 0.5802 - accuracy: 0.9653 - val_loss: 0.5938 - val_accuracy: 0.9600
# Epoch 18/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5943 - accuracy: 0.9606 - val_loss: 0.5883 - val_accuracy: 0.9600
# Epoch 19/50
# 216/216 [==============================] - 62s 285ms/step - loss: 0.5871 - accuracy: 0.9514 - val_loss: 0.5821 - val_accuracy: 0.9600
# Epoch 20/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5663 - accuracy: 0.9676 - val_loss: 0.5790 - val_accuracy: 0.9600
# Epoch 21/50
# 216/216 [==============================] - 61s 281ms/step - loss: 0.5815 - accuracy: 0.9583 - val_loss: 0.5728 - val_accuracy: 0.9600
# Epoch 22/50
# 216/216 [==============================] - 57s 264ms/step - loss: 0.5673 - accuracy: 0.9583 - val_loss: 0.5688 - val_accuracy: 0.9600
# Epoch 23/50
# 216/216 [==============================] - 62s 287ms/step - loss: 0.5596 - accuracy: 0.9699 - val_loss: 0.5665 - val_accuracy: 0.9600
# Epoch 24/50
# 216/216 [==============================] - 62s 287ms/step - loss: 0.5617 - accuracy: 0.9699 - val_loss: 0.5665 - val_accuracy: 0.9600
# Epoch 25/50
# 216/216 [==============================] - 61s 282ms/step - loss: 0.5613 - accuracy: 0.9676 - val_loss: 0.5579 - val_accuracy: 0.9600
# Epoch 26/50
# 216/216 [==============================] - 61s 284ms/step - loss: 0.5612 - accuracy: 0.9468 - val_loss: 0.5630 - val_accuracy: 0.9600
# Epoch 27/50
# 216/216 [==============================] - 62s 289ms/step - loss: 0.5520 - accuracy: 0.9676 - val_loss: 0.5584 - val_accuracy: 0.9600
# Epoch 28/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5601 - accuracy: 0.9653 - val_loss: 0.5550 - val_accuracy: 0.9600
# Epoch 29/50
# 216/216 [==============================] - 61s 285ms/step - loss: 0.5704 - accuracy: 0.9583 - val_loss: 0.5537 - val_accuracy: 0.9600
# Epoch 30/50
# 216/216 [==============================] - 61s 284ms/step - loss: 0.5369 - accuracy: 0.9769 - val_loss: 0.5546 - val_accuracy: 0.9600
# Epoch 31/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5581 - accuracy: 0.9606 - val_loss: 0.5509 - val_accuracy: 0.9600
# Epoch 32/50
# 216/216 [==============================] - 62s 287ms/step - loss: 0.5486 - accuracy: 0.9653 - val_loss: 0.5495 - val_accuracy: 0.9600
# Epoch 33/50
# 216/216 [==============================] - 56s 258ms/step - loss: 0.5524 - accuracy: 0.9583 - val_loss: 0.5504 - val_accuracy: 0.9600
# Epoch 34/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5381 - accuracy: 0.9722 - val_loss: 0.5495 - val_accuracy: 0.9600
# Epoch 35/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5370 - accuracy: 0.9769 - val_loss: 0.5471 - val_accuracy: 0.9600
# Epoch 36/50
# 216/216 [==============================] - 61s 280ms/step - loss: 0.5274 - accuracy: 0.9769 - val_loss: 0.5482 - val_accuracy: 0.9600
# Epoch 37/50
# 216/216 [==============================] - 66s 305ms/step - loss: 0.5277 - accuracy: 0.9792 - val_loss: 0.5457 - val_accuracy: 0.9600
# Epoch 38/50
# 216/216 [==============================] - 62s 289ms/step - loss: 0.5409 - accuracy: 0.9676 - val_loss: 0.5474 - val_accuracy: 0.9600
# Epoch 39/50
# 216/216 [==============================] - 61s 284ms/step - loss: 0.5509 - accuracy: 0.9630 - val_loss: 0.5429 - val_accuracy: 0.9600
# Epoch 40/50
# 216/216 [==============================] - 56s 261ms/step - loss: 0.5403 - accuracy: 0.9653 - val_loss: 0.5427 - val_accuracy: 0.9600
# Epoch 41/50
# 216/216 [==============================] - 62s 289ms/step - loss: 0.5391 - accuracy: 0.9722 - val_loss: 0.5415 - val_accuracy: 0.9600
# Epoch 42/50
# 216/216 [==============================] - 62s 286ms/step - loss: 0.5362 - accuracy: 0.9699 - val_loss: 0.5452 - val_accuracy: 0.9600
# Epoch 43/50
# 216/216 [==============================] - 58s 266ms/step - loss: 0.5364 - accuracy: 0.9745 - val_loss: 0.5421 - val_accuracy: 0.9600
# Epoch 44/50
# 216/216 [==============================] - 60s 279ms/step - loss: 0.5538 - accuracy: 0.9653 - val_loss: 0.5415 - val_accuracy: 0.9600
# Epoch 45/50
# 216/216 [==============================] - 60s 280ms/step - loss: 0.5311 - accuracy: 0.9792 - val_loss: 0.5383 - val_accuracy: 0.9600
# Epoch 46/50
# 216/216 [==============================] - 62s 288ms/step - loss: 0.5284 - accuracy: 0.9745 - val_loss: 0.5413 - val_accuracy: 0.9600
# Epoch 47/50
# 216/216 [==============================] - 62s 287ms/step - loss: 0.5236 - accuracy: 0.9792 - val_loss: 0.5415 - val_accuracy: 0.9600
# Epoch 48/50
# 216/216 [==============================] - 62s 288ms/step - loss: 0.5383 - accuracy: 0.9792 - val_loss: 0.5420 - val_accuracy: 0.9600
# Epoch 49/50
# 216/216 [==============================] - 62s 287ms/step - loss: 0.5385 - accuracy: 0.9722 - val_loss: 0.5409 - val_accuracy: 0.9600
# Epoch 50/50
# 216/216 [==============================] - 61s 281ms/step - loss: 0.5252 - accuracy: 0.9792 - val_loss: 0.5415 - val_accuracy: 0.9600

# %% [markdown]
# ##Model Evaluation

# %%
loss, acc = model.evaluate(test_data)
print(f'Test loss:{loss}, Test accuracy:{acc}')
# Out:
# 1/1 [==============================] - 15s 15s/step - loss: 0.6094 - accuracy: 0.9583
# Test loss:0.6093873381614685, Test accuracy:0.9583333134651184

# %% [markdown]
# ##Model Conversion

# %%
model.export_model()

# %%
# !ls exported_model
files.download('exported_model/model.tflite')
# Out:
# checkpoint  metadata.json  model.tflite  summaries

# %% [markdown]
# ### Retraining parameters
#
# > Indented block
#
#
#
# You can further customize how the retraining process runs to adjust training time and potentially increase the retrained model's performance. *These parameters are optional*. Use the `ImageClassifierModelOptions` class and the `HParams` class to set these additional options.
#
# Use the `ImageClassifierModelOptions` class parameters to customize the existing model. It has the following customizable parameter that affects model accuracy:
# * `dropout_rate`: The fraction of the input units to drop. Used in dropout layer. Defaults to 0.05.
#
# Use the `HParams` class to customize other parameters related to training and saving the model:
#
# * `learning_rate`: The learning rate to use for gradient descent training. Defaults to 0.001.
# * `batch_size`: Batch size for training. Defaults to 2.
# * `epochs`: Number of training iterations over the dataset. Defaults to 10.
# * `steps_per_epoch`: An optional integer that indicates the number of training steps per epoch. If not set, the training pipeline calculates the default steps per epoch as the training dataset size divided by batch size.
# * `shuffle`: True if the dataset is shuffled before training. Defaults to False.
# * `do_fine_tuning`: If true, the base module is trained together with the classification layer on top. This defaults to False, which means only the classification layer is trained and pre-trained weights for the base module are frozen.
# * `l1_regularizer`: A regularizer that applies a L1 regularization penalty. Defaults to 0.0.
# * `l2_regularizer`: A regularizer that applies a L2 regularization penalty. Defaults to 0.0001.
# * `label_smoothing`: Amount of label smoothing to apply. See [`tf.keras.losses`](https://www.tensorflow.org/api_docs/python/tf/keras/losses) for more details. Defaults to 0.1.
# * `do_data_augmentation`: Whether or not the training dataset is augmented by applying random transformations such as cropping, flipping, etc. See [utils.image_preprocessing](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image) for details. Defaults to True.
# * `decay_samples`: Number of training samples used to calculate the decay steps and create the training optimizer. Defaults to 2,560,000.
# * `warmup_epochs`: Number of warmup steps for a linear increasing warmup schedule on the learning rate. Used to set up warmup schedule by `model_util.WarmUp`. Defaults to 2.

# %%
hparams=image_classifier.HParams(epochs=15, export_dir="exported_model_2")
options = image_classifier.ImageClassifierOptions(supported_model=spec, hparams=hparams)
model_2 = image_classifier.ImageClassifier.create(
    train_data = train_data,
    validation_data = validation_data,
    options=options,
)

# %%
loss, accuracy = model_2.evaluate(test_data)

# %%
model.export_model()
